# %% [markdown]
# ## Selectores JavaScript

# %% [markdown]
# #### Métodos tradicionales (getElementBy)

# %%
// Seleccionar por ID
document.getElementById('miId');

# %%
// Seleccionar por clase (HTMLCollection)
document.getElementsByClassName('miClase');

# %%
// Seleccionar por tag (HTMLCollection)
document.getElementsByTagName('div');

# %%
// Seleccionar por name (NodeList)
document.getElementsByName('username');

# %% [markdown]
# **Nota:** Los HTMLCollections y Nodelists se seleccionan individualmente (por índice),
# para poder aplicarles estilos:

# %%
elemento[0].style.color = 'red';

# %% [markdown]
# #### Métodos modernos (querySelector)

# %% [markdown]
# ##### Seleccionar el primer elemento que coincida:

# %%
document.querySelector('.clase'); // Por clase
document.querySelector('#id'); // Por ID
document.querySelector('div'); // Por etiqueta
document.querySelector('[data-atributo]'); // Por atributo

# %% [markdown]
# ##### Seleccionar todos los elementos que coincidan (NodeList):

# %%
document.querySelectorAll('.clase'); // Por clase
document.querySelectorAll('div.highlight'); // Por clase y etiqueta
document.querySelectorAll('input[type="text"]'); // Por atributo
document.querySelectorAll('ul li'); // Por etiqueta dentro de una lista
document.querySelectorAll('p'); // Todos los párrafos

# %% [markdown]
# ## Manipulación del DOM

# %% [markdown]
# #### Creación y Manipulación de Nodos

# %%
// Crear elementos:
const nuevoDiv = document.createElement('div');
const nuevoTexto = document.createTextNode('Hola mundo');

# %%
// Modificar elementos:
elemento.textContent = 'Nuevo texto';
elemento.innerHTML = '<strong>Texto</strong> con HTML';
elemento.setAttribute('src', 'imagen2.jpg');}
elemento.classList.add('ocultar');
elemento.classList.remove('clase-vieja');
elemento.classList.toggle('clase-activa');
elemento.style.color = 'blue';

# %% [markdown]
# **Nota:** Las propiedades CSS en JavaScript se escriben en camelCase<br>
# Ejemplo: "background-color" (CSS) se convierte en "backgroundColor" (JavaScript)

# %%
// Insertar elementos:
padre.appendChild(elemento); // Al final
padre.insertBefore(nuevo, referencia); // Antes de referencia
padre.prepend(elemento); // Al principio (moderno)
padre.append(elemento); // Al final (moderno)

# %%
// Clonar elementos:
const clon = elemento.cloneNode(true); // true = copia profunda

# %%
// Eliminar elementos:
elemento.remove(); // Moderno
padre.removeChild(elemento); // Tradicional

# %%
// Reemplazar elementos:
padre.replaceChild(nuevo, viejo);
